# %% [markdown]
# <h1 align="center"><font size = 14>Hands-On Machine Learning</font></h1>
# <h3 align="center"><font size = 7>Decision Tree</font></h3>
# <h3 align="center">Zahra Amini</h3>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# # Part 01

# %% [markdown]
# # Decision Tree Classifier

# %% [markdown]
# # 0. Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.model_selection import train_test_split

import category_encoders
import category_encoders as ce

from sklearn.tree import DecisionTreeClassifier

from sklearn.tree import plot_tree

from sklearn.metrics import accuracy_score

from sklearn import tree

from sklearn.metrics import confusion_matrix

from sklearn.metrics import classification_report

from sklearn.model_selection import GridSearchCV

from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import plot_confusion_matrix

# %%
pip install category_encoders
# Out:
# Collecting category_encoders
#   Downloading category_encoders-2.5.1.post0-py2.py3-none-any.whl (72 kB)
#      -------------------------------------- 72.4/72.4 kB 440.8 kB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.0.5 in c:\users\amini\anaconda3\lib\site-packages (from category_encoders) (1.4.4)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\amini\anaconda3\lib\site-packages (from category_encoders) (1.9.1)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\amini\anaconda3\lib\site-packages (from category_encoders) (0.13.2)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\amini\anaconda3\lib\site-packages (from category_encoders) (0.5.2)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\amini\anaconda3\lib\site-packages (from category_encoders) (1.0.2)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\amini\anaconda3\lib\site-packages (from category_encoders) (1.21.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\amini\anaconda3\lib\site-packages (from pandas>=1.0.5->category_encoders) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\amini\anaconda3\lib\site-packages (from pandas>=1.0.5->category_encoders) (2.8.2)
# Requirement already satisfied: six in c:\users\amini\anaconda3\lib\site-packages (from patsy>=0.5.1->category_encoders) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\amini\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\amini\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (1.1.1)
# Requirement already satisfied: packaging>=21.3 in c:\users\amini\anaconda3\lib\site-packages (from statsmodels>=0.9.0->category_encoders) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\amini\anaconda3\lib\site-packages (from packaging>=21.3->statsmodels>=0.9.0->category_encoders) (3.0.9)
# Installing collected packages: category_encoders
# Successfully installed category_encoders-2.5.1.post0
# Note: you may need to restart the kernel to use updated packages.

# %%
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# # 1. Read data

# %%
path = 'car_evaluation.csv'

df = pd.read_csv(path, header=None)

# %% [markdown]
# # 2. Exploratory data analysis

# %%
df.shape
# Out:
# (1728, 7)

# %%
df.head()
# Out:
#        0      1  2  3      4     5      6
# 0  vhigh  vhigh  2  2  small   low  unacc
# 1  vhigh  vhigh  2  2  small   med  unacc
# 2  vhigh  vhigh  2  2  small  high  unacc
# 3  vhigh  vhigh  2  2    med   low  unacc
# 4  vhigh  vhigh  2  2    med   med  unacc

# %%
# Rename column names

col_names = ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'class']


df.columns = col_names

col_names
# Out:
# ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'class']

# %%
# let's again preview the dataset

df.head()
# Out:
#   buying  maint doors persons lug_boot safety  class
# 0  vhigh  vhigh     2       2    small    low  unacc
# 1  vhigh  vhigh     2       2    small    med  unacc
# 2  vhigh  vhigh     2       2    small   high  unacc
# 3  vhigh  vhigh     2       2      med    low  unacc
# 4  vhigh  vhigh     2       2      med    med  unacc

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1728 entries, 0 to 1727
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   buying    1728 non-null   object
#  1   maint     1728 non-null   object
#  2   doors     1728 non-null   object
#  3   persons   1728 non-null   object
#  4   lug_boot  1728 non-null   object
#  5   safety    1728 non-null   object
#  6   class     1728 non-null   object
# dtypes: object(7)
# memory usage: 94.6+ KB

# %%
df['class'].unique()
# Out:
# array(['unacc', 'acc', 'vgood', 'good'], dtype=object)

# %%
df['class'].value_counts()
# Out:
# unacc    1210
# acc       384
# good       69
# vgood      65
# Name: class, dtype: int64

# %% [markdown]
# ### Missing values in variables

# %%
# check missing values in variables

df.isnull().sum()
# Out:
# buying      0
# maint       0
# doors       0
# persons     0
# lug_boot    0
# safety      0
# class       0
# dtype: int64

# %% [markdown]
# # 3. X, y

# %%
X = df.drop(['class'], axis=1)

y = df['class']

# %%
X.shape
# Out:
# (1728, 6)

# %% [markdown]
# # 4. train test split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train.shape, X_test.shape
# Out:
# ((1209, 6), (519, 6))

# %% [markdown]
# # 5. Preprocessing

# %%
X_train.dtypes
# Out:
# buying      object
# maint       object
# doors       object
# persons     object
# lug_boot    object
# safety      object
# dtype: object

# %%
X.columns
# Out:
# Index(['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety'], dtype='object')

# %% [markdown]
# ### Encode categorical variables

# %%
encoder = ce.OrdinalEncoder(cols=['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety'])

# %%
X_train = encoder.fit_transform(X_train)

# %%
X_test = encoder.transform(X_test)

# %%
X_train
# Out:
#       buying  maint  doors  persons  lug_boot  safety
# 1178       1      1      1        1         1       1
# 585        2      2      2        2         2       2
# 1552       3      1      2        1         3       3
# 1169       1      1      1        3         1       1
# 1033       1      2      3        3         1       3
# ...      ...    ...    ...      ...       ...     ...
# 1130       1      1      2        2         3       1
# 1294       1      4      1        2         1       3
# 860        2      4      1        2         3       1
# 1459       3      2      3        3         2       3
# 1126       1      1      2        2         2       3
#
# [1209 rows x 6 columns]

# %% [markdown]
# # 6. Decision Tree Classifier with criterion gini index

# %%
clf_gini = DecisionTreeClassifier(criterion='gini', max_depth = 3, random_state=42)

# %%
clf_gini.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=42)

# %% [markdown]
# ### Predict the Test set results with criterion gini index

# %%
y_pred_gini = clf_gini.predict(X_test)

# %% [markdown]
# ### Check accuracy score with criterion gini index

# %%
accuracy_score(y_test, y_pred_gini)
# Out:
# 0.7591522157996147

# %% [markdown]
# ### Compare the train-set and test-set accuracy

# %%
y_pred_train = clf_gini.predict(X_train)

# %% [markdown]
# ### Check for overfitting and underfitting

# %%
accuracy_score(y_train, y_pred_train)
# Out:
# 0.7766749379652605

# %% [markdown]
# ### feature importances

# %%
clf_gini.feature_importances_
# Out:
# array([0.04933822, 0.        , 0.        , 0.35364516, 0.        ,
#        0.59701662])

# %%
X
# Out:
#      buying  maint  doors persons lug_boot safety
# 0     vhigh  vhigh      2       2    small    low
# 1     vhigh  vhigh      2       2    small    med
# 2     vhigh  vhigh      2       2    small   high
# 3     vhigh  vhigh      2       2      med    low
# 4     vhigh  vhigh      2       2      med    med
# ...     ...    ...    ...     ...      ...    ...
# 1723    low    low  5more    more      med    med
# 1724    low    low  5more    more      med   high
# 1725    low    low  5more    more      big    low
# 1726    low    low  5more    more      big    med
# 1727    low    low  5more    more      big   high
#
# [1728 rows x 6 columns]

# %% [markdown]
# ### Visualize decision-trees

# %%
# plt.figure(figsi

plot_tree(clf_gini, filled=True, feature_names=X.columns);

# %%
(X_train['persons']<=2.5).sum()
# Out:
# 816

# %%
clf_gini.max_depth
# Out:
# 3

# %% [markdown]
# # 7. Decision Tree Classifier with criterion entropy

# %%
clf_ent = DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=42)

# %%
clf_ent.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=42)

# %% [markdown]
# ### Predict the Test set results with criterion entropy

# %%
y_pred_ent = clf_ent.predict(X_test)

# %%
y_pred_ent
# Out:
# array(['unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc',
#        'unacc', 'unacc', 'unacc', 'acc', 'acc', 'unacc', 'unacc', 'unacc',
#        'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc',
#        'acc', 'unacc', 'unacc', 'unacc', 'acc', 'unacc', 'unacc', 'unacc',
#        'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc',
#        'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc',
#        'acc', 'acc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc',
#        'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc',
#        'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'acc',
#        'unacc', 'acc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc',
#        'unacc', 'acc', 'acc', 'unacc', 'unacc', 'unacc', 'unacc', 'acc',
#        'unacc', 'unacc', 'unacc', 'acc', 'unacc', 'unacc', 'unacc', 'acc',
#        'acc', 'unacc', 'acc', 'unacc', 'unacc', 'unacc', 'unacc', 'acc',
#        'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc',
#        'unacc', 'acc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc',
#        'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'acc', 'unacc',
#        'unacc', 'unacc', 'unacc', 'acc', 'unacc', 'unacc', 'unacc',
#        'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc',
#        'unacc', 'unacc', 'unacc', 'acc', 'unacc', 'acc', 'unacc', 'unacc',
#        'unacc', 'unacc', 'acc', 'unacc', 'unacc', 'unacc', 'unacc', 'acc',
#        'unacc', 'unacc', 'acc', 'acc', 'unacc', 'unacc', 'unacc', 'unacc',
#        'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'acc', 'unacc',
#        'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'acc', 'acc', 'acc',
#        'unacc', 'acc', 'unacc', 'unacc', 'acc', 'unacc', 'unacc', 'unacc',
#        'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'acc',
#        'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc',
#        'unacc', 'unacc', 'unacc', 'unacc', 'acc', 'unacc', 'unacc',
#        'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc',
#        'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc',
#        'unacc', 'acc', 'unacc', 'unacc', 'unacc', 'acc', 'acc', 'unacc',
#        'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'acc',
#        'unacc', 'unacc', 'unacc', 'acc', 'unacc', 'acc', 'unacc', 'unacc',
#        'acc', 'unacc', 'acc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc',
#        'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc',
#        'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc',
#        'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc',
#        'unacc', 'acc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc',
#        'unacc', 'acc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc',
#        'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc',
#        'acc', 'acc', 'unacc', 'unacc', 'unacc', 'unacc', 'acc', 'unacc',
#        'acc', 'acc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'acc',
#        'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc',
#        'acc', 'acc', 'acc', 'unacc', 'unacc', 'unacc', 'acc', 'unacc',
#        'unacc', 'acc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc',
#        'unacc', 'unacc', 'acc', 'unacc', 'unacc', 'unacc', 'unacc', 'acc',
#        'unacc', 'unacc', 'acc', 'unacc', 'acc', 'unacc', 'unacc', 'unacc',
#        'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc',
#        'unacc', 'unacc', 'unacc', 'acc', 'unacc', 'unacc', 'acc', 'unacc',
#        'unacc', 'unacc', 'acc', 'unacc', 'unacc', 'unacc', 'unacc', 'acc',
#        'unacc', 'acc', 'unacc', 'unacc', 'unacc', 'acc', 'unacc', 'acc',
#        'acc', 'acc', 'unacc', 'unacc', 'unacc', 'acc', 'unacc', 'unacc',
#        'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc',
#        'unacc', 'unacc', 'unacc', 'acc', 'unacc', 'unacc', 'unacc',
#        'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc',
#        'unacc', 'unacc', 'unacc', 'unacc', 'acc', 'unacc', 'unacc', 'acc',
#        'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc',
#        'acc', 'unacc', 'acc', 'unacc', 'acc', 'unacc', 'unacc', 'acc',
#        'unacc', 'unacc', 'acc', 'unacc', 'unacc', 'unacc', 'acc', 'unacc',
#        'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc',
#        'acc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc',
#        'unacc', 'acc', 'unacc', 'unacc', 'unacc', 'acc', 'unacc', 'acc',
#        'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc',
#        'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc',
#        'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc',
#        'unacc', 'unacc', 'unacc', 'acc', 'unacc', 'unacc', 'unacc',
#        'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc',
#        'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'acc', 'unacc',
#        'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc',
#        'acc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'acc', 'unacc',
#        'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc', 'unacc',
#        'unacc'], dtype=object)

# %% [markdown]
# ### Check accuracy score with criterion entropy

# %%
accuracy_score(y_test, y_pred_ent)
# Out:
# 0.7591522157996147

# %% [markdown]
# ### Compare the train-set and test-set accuracy

# %% [markdown]
# ### Check for overfitting and underfitting

# %% [markdown]
# ### Visualize decision-trees

# %%
plot_tree(clf_ent, filled=True, feature_names=X.columns);

# %% [markdown]
# # 8. Confusion matrix

# %%
plot_confusion_matrix(clf_ent, X_test, y_test)

# %% [markdown]
# # 9. Classification Report

# %%
print(classification_report(y_test, y_pred_ent))
# Out:
#               precision    recall  f1-score   support
#
#          acc       0.52      0.37      0.43       118
#         good       0.00      0.00      0.00        19
#        unacc       0.81      0.98      0.88       358
#        vgood       0.00      0.00      0.00        24
#
#     accuracy                           0.76       519
#    macro avg       0.33      0.34      0.33       519
# weighted avg       0.67      0.76      0.71       519

# %% [markdown]
# # 10. Understanding Hyperparameters

# %% [markdown]
# ### Max Depth

# %% [markdown]
# ### Max Leaf Nodes

# %%
Leaf = DecisionTreeClassifier(max_leaf_nodes= 5)

# %%
Leaf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_leaf_nodes=5)

# %%
plot_tree(Leaf, filled=True, feature_names=X.columns);

# %% [markdown]
# # Part 02
#
# # Random Forest

# %%
n_estimators = [64, 100, 128, 200]

max_features=[2, 3, 4]

bootstrap = [True, False]

# %%
param_grid = {'n_estimators':n_estimators,
             'max_features':max_features,
             'bootstrap':bootstrap}

# %%
RF = RandomForestClassifier()

# %%
grid = GridSearchCV(RF, param_grid, cv=5)

# %%
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'bootstrap': [True, False], 'max_features': [2, 3, 4],
#                          'n_estimators': [64, 100, 128, 200]})

# %%
grid.best_params_
# Out:
# {'bootstrap': False, 'max_features': 4, 'n_estimators': 100}

# %%
y_pred = grid.predict(X_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          acc       0.90      0.88      0.89       118
#         good       0.77      0.89      0.83        19
#        unacc       0.97      0.98      0.98       358
#        vgood       0.86      0.75      0.80        24
#
#     accuracy                           0.94       519
#    macro avg       0.88      0.88      0.87       519
# weighted avg       0.94      0.94      0.94       519

# %%
RF_OOB = RandomForestClassifier(max_features=4, n_estimators=100, oob_score=True)

# %%
RF_OOB.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_features=4, oob_score=True)

# %%
RF_OOB.oob_score_
# Out:
# 0.9520264681555004

# %%
1 - RF_OOB.oob_score_
# Out:
# 0.047973531844499595
